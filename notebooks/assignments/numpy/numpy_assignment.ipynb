# %% [markdown]
# ### 📝 Task 1: Weekly Shop Sales Analysis
#
# A retail shop recorded daily sales (in NPR) for 4 weeks.
#
# Create a NumPy array representing sales data with shape (4, 7).
#
# Perform the following analysis:
#
# - Total sales per week
# - Average daily sales
# - Day with highest sales overall
# - Percentage growth from Week 1 to Week 4

# %% [markdown]
# ### 📝 Task 2: Student Performance Improvement System
#
# Marks of 30 students are stored in a NumPy array.
#
# The school decides to:
#
# - Add 5 grace marks to every student
# - Cap maximum marks at 100
# - Identify students who passed (≥ 40)
# - Calculate pass percentage
#
# Display comparison before and after grace marks.

# %% [markdown]
# ### 📝 Task 3: Temperature Monitoring System
#
# A weather station records hourly temperature for 5 days.
#
# Store the data in a NumPy array.
#
# Analyze:
#
# - Average temperature per day
# - Hottest day
# - Coldest recorded temperature
# - Hours where temperature exceeded 30°C

# %% [markdown]
# ### 📝 Task 4: Image Brightness Adjustment (Matrix Scaling)
#
# A grayscale image is represented as a matrix of pixel intensities (0–255).
#
# Using NumPy:
#
# - Increase brightness by 20%
# - Ensure values do not exceed 255
# - Normalize pixel values between 0 and 1
#
# Explain how broadcasting is used.

# %% [markdown]
# ### 📝 Task 5: Product Price Optimization
#
# A store sells 5 products across 3 branches.
#
# Store product prices in a matrix.
#
# Perform:
#
# - Apply 10% discount on all products
# - Find average price per product
# - Identify branch with highest overall price
# - Reshape data to compare branch performance

# %% [markdown]
# ### 📝 Task 6: Fitness Tracking Data Analysis
#
# A fitness tracker records daily steps for 50 users.
#
# Analyze:
#
# - Mean and median step count
# - Standard deviation
# - Users above recommended 10,000 steps
# - Percentage of active users

# %% [markdown]
# ### 📝 Task 7: Investment Portfolio Return Calculation
#
# A person invests in multiple assets.
#
# Use NumPy arrays to store:
#
# - Investment amounts
# - Annual return rates
#
# Calculate:
#
# - Total portfolio return
# - Weighted return
# - Best performing asset

# %% [markdown]
# ### 📝 Task 8: Solving Engineering Equations (Linear Algebra)
#
# A system of linear equations represents electrical currents in a circuit.
#
# Using NumPy:
#
# - Represent the system in matrix form
# - Solve for unknown variables
# - Verify solution by substitution

# %% [markdown]
# ### 📝 Task 9: School Result Analytics Dashboard
#
# Marks of students across 5 subjects are stored in a 2D array.
#
# Generate:
#
# - Average marks per student
# - Average marks per subject
# - Top performing student
# - Subject with lowest average score

# %% [markdown]
# ### 📝 Task 10: Data Normalization for Machine Learning
#
# A dataset contains different ranges of values.
#
# Using NumPy:
#
# - Apply Min-Max normalization
# - Apply standardization (z-score)
# - Compare distributions before and after scaling
