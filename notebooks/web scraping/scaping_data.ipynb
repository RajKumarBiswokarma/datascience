# %% [markdown]
# ## Lecture Objective
#
# In the previous lecture, we extracted information from the **main listing page** of the website.
#
# From each product container we collected:
#
# - Book title
# - Book price
# - Book rating
# - Stock availability
#
# However, the listing page does not contain **complete product details**.
#
# Each book has its own **individual product page** containing additional information such as:
#
# - Product description
# - Product genre (category)
# - Product information table
# - UPC
# - Product type
# - Price excluding tax
# - Price including tax
# - Availability
# - Number of reviews
#
# In this lecture we will learn how to visit each product page and extract this detailed information.

# %% [markdown]
# ## Collecting Product Links
#
# Before scraping individual product pages, we must first collect the **URL of each product**.
#
# Each product container contains a link pointing to the book's page.
#
# In this step we will:
#
# 1. Locate the anchor tag inside each product container
# 2. Extract the `href` attribute
# 3. Construct the full product URL
# 4. Store all product links inside a list

# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

# Scrape the main listing page (carried over from previous lecture)
base_url = 'https://books.toscrape.com/'
response = requests.get(base_url + 'index.html')
soup = BeautifulSoup(response.content, 'html.parser')

# Re-build the listing page dataset from the previous lecture
rating_map = {'One': 1, 'Two': 2, 'Three': 3, 'Four': 4, 'Five': 5}

listing_data = []
product_containers = soup.find_all('article', class_='product_pod')

for product in product_containers:
    title       = product.find('h3').find('a')['title']
    price       = product.find('p', class_='price_color').text.strip()
    rating_word = product.find('p', class_='star-rating')['class'][1]
    rating      = rating_map[rating_word]
    stock       = product.find('p', class_='instock availability').text.strip()
    listing_data.append({'Title': title, 'Price': price, 'Rating': rating, 'Stock Availability': stock})

listing_df = pd.DataFrame(listing_data)
print(f'Listing page records: {len(listing_df)}')
listing_df.head()
# Out:
# Listing page records: 20
#                                    Title   Price  Rating Stock Availability
# 0                   A Light in the Attic  £51.77       3           In stock
# 1                     Tipping the Velvet  £53.74       1           In stock
# 2                             Soumission  £50.10       1           In stock
# 3                          Sharp Objects  £47.82       4           In stock
# 4  Sapiens: A Brief History of Humankind  £54.23       5           In stock

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    All products | Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="" name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
print(product_containers)
# Out:
# [<article class="product_pod">
# <div class="image_container">
# <a href="catalogue/a-light-in-the-attic_1000/index.html"><img alt="A Light in the Attic" class="thumbnail" src="media/cache/2c/da/2cdad67c44b002e7ead0cc35693c0e8b.jpg"/></a>
# </div>
# <p class="star-rating Three">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="catalogue/a-light-in-the-attic_1000/index.html" title="A Light in the Attic">A Light in the ...</a></h3>
# <div class="product_price">
# <p class="price_color">£51.77</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>, <article class="product_pod">
# <div class="image_container">
# ...

# %%
product_links = []

for product in product_containers:
    relative_link = product.find('h3').find('a')['href']
    print(relative_link)
    
    full_url = base_url + relative_link
    product_links.append(full_url)
    
product_links[:3]
# Out:
# catalogue/a-light-in-the-attic_1000/index.html
# catalogue/tipping-the-velvet_999/index.html
# catalogue/soumission_998/index.html
# catalogue/sharp-objects_997/index.html
# catalogue/sapiens-a-brief-history-of-humankind_996/index.html
# catalogue/the-requiem-red_995/index.html
# catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html
# catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html
# catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html
# catalogue/the-black-maria_991/index.html
# catalogue/starving-hearts-triangular-trade-trilogy-1_990/index.html
# catalogue/shakespeares-sonnets_989/index.html
# catalogue/set-me-free_988/index.html
# catalogue/scott-pilgrims-precious-little-life-scott-pilgrim-1_987/index.html
# catalogue/rip-it-up-and-start-again_986/index.html
# ...

# %%
len(product_links)
# Out:
# 20

# %%
# Create empty list for storing product links

# Define base website URL

# Loop through product containers

# Extract product link

# Append full product URL to list

# Display first few links

# %% [markdown]
# ##  Visit a single product page
#
# Before scraping multiple product pages, it is useful to test the process on **one product page**.
#
# In this step we will:
#
# 1. Select one product link
# 2. Send a request to the webpage
# 3. Parse the HTML structure
#
# This allows us to inspect the page and identify where the required information is located.

# %%
# Select first product link
first_product_link = product_links[0]

# Send HTTP request
first_book_response = requests.get(first_product_link)

# Parse HTML using BeautifulSoup
product_soup = BeautifulSoup(first_book_response.content, 'html.parser')

print(first_book_response.status_code)
# Out:
# 200

# %%
product_soup
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!--> <html class="no-js" lang="en-us"> <!--<![endif]-->
# <head>
# <title>
#     A Light in the Attic | Books to Scrape - Sandbox
# </title>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="24th Jun 2016 09:29" name="created"/>
# <meta content="
# ...

# %% [markdown]
# ## Extract Product Description
#
# The product description is located in the section labeled **Product Description**.
#
# In the HTML structure, this section contains:
#
# - a div element with id `product_description`
# - the actual description text inside the next paragraph element
#
# In this step we will locate this section and extract the description text.

# %%
# Locate description section using id
descriptio_header = product_soup.find(id ='product_description')

# Find the paragraph element containing the description
desciption = descriptio_header.find_next_sibling('p').text.strip()
print(desciption)


# Extract description text

# Print extracted description
# Out:
# It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love th It's hard to imagine a world without A Light in the Attic. This now-classic collection of poetry and drawings from Shel Silverstein celebrates its 20th anniversary with this special edition. Silverstein's humorous and creative verse can amuse the dowdiest of readers. Lemon-faced adults and fidgety kids sit still and read these rhythmic words and laugh and smile and love that Silverstein. Need proof of his genius? RockabyeRockabye baby, in the treetopDon't you know a treetopIs no safe place to rock?And who put you up there,And your cradle, too?Baby, I think someone down here'sGot it in for you. Shel, you never sound
# ...

# %% [markdown]
# ## Extract Product Genre
#
# The product genre (category) is located in the **breadcrumb navigation** at the top of the page.
#
# The breadcrumb shows the navigation hierarchy of the page.
#
# Example structure:
#
# Home → Books → Poetry → Book Title
#
# The third element usually represents the **genre of the book**.

# %%
# Locate breadcrumb navigation
breadcrumb = product_soup.find('ul', class_ = 'breadcrumb')

# Extractlist items from breadcrumb
breadcrumb_list = breadcrumb.find_all('li')

# Identify genre element
genre = breadcrumb_list[2].text.strip()


# Extract and print genre
print("genre:", genre)
# Out:
# genre: Poetry

# %% [markdown]
# ## Extract Product Information Table
#
# Each product page contains a table that stores additional product information.
#
# The table includes fields such as:
#
# - UPC
# - Product Type
# - Price (excluding tax)
# - Price (including tax)
# - Tax
# - Availability
# - Number of reviews
#
# In this step we will locate the table and extract its contents.

# %%
# Locate product information table
table = product_soup.find("table", class_ = 'table-striped')

# Extract all table rows
rows = table.find_all('tr')

# Iterate through rows
# Extract column names and values

for row in rows:
    col_name = row.find('th').text.strip()
    col_value = row.find('td').text.strip()
    print(f'{col_name}: {col_value}')
# Out:
# UPC: a897fe39b1053632
# Product Type: Books
# Price (excl. tax): £51.77
# Price (incl. tax): £51.77
# Tax: £0.00
# Availability: In stock (22 available)
# Number of reviews: 0

# %% [markdown]
# ## Convert Table into a Dictionary
#
# To organize the extracted table data, we will store it in a dictionary.
#
# A dictionary allows us to map each field name to its corresponding value.
#
# Example structure:
#
# {
#     "UPC": "...",
#     "Product Type": "...",
#     "Price (excl tax)": "...",
#     "Availability": "..."
# }
#
# This structure makes it easier to convert the data into a DataFrame later.

# %%
# Create empty dictionary
# Loop through table rows
# Extract key and value
# Store them in dictionary
# Display extracted dictionary
table_dict = {}

for row in rows:
    col_name = row.find('th').text.strip()
    col_value = row.find('td').text.strip()
    table_dict[col_name] = col_value

# %%
table_dict
# Out:
# {'UPC': 'a897fe39b1053632',
#  'Product Type': 'Books',
#  'Price (excl. tax)': '£51.77',
#  'Price (incl. tax)': '£51.77',
#  'Tax': '£0.00',
#  'Availability': 'In stock (22 available)',
#  'Number of reviews': '0'}

# %% [markdown]
# ## Scrape Multiple Product Pages
#
# Once we understand how to extract information from a single product page, we can apply the same logic to multiple product links.
#
# In this step we will:
#
# 1. Loop through the list of product links
# 2. Send requests to each page
# 3. Extract description, genre, and product information
# 4. Store results in a list

# %%
product_links
# Out:
# ['https://books.toscrape.com/catalogue/a-light-in-the-attic_1000/index.html',
#  'https://books.toscrape.com/catalogue/tipping-the-velvet_999/index.html',
#  'https://books.toscrape.com/catalogue/soumission_998/index.html',
#  'https://books.toscrape.com/catalogue/sharp-objects_997/index.html',
#  'https://books.toscrape.com/catalogue/sapiens-a-brief-history-of-humankind_996/index.html',
#  'https://books.toscrape.com/catalogue/the-requiem-red_995/index.html',
#  'https://books.toscrape.com/catalogue/the-dirty-little-secrets-of-getting-your-dream-job_994/index.html',
#  'https://books.toscrape.com/catalogue/the-coming-woman-a-novel-based-on-the-life-of-the-infamous-feminist-victoria-woodhull_993/index.html',
#  'https://books.toscrape.com/catalogue/the-boys-in-the-boat-nine-americans-and-their-epic-quest-for-gold-at-the-1936-berlin-olympics_992/index.html',
#  'https://books.toscrape.com/catalogue/the-black-maria_991/index.html',
# ...

# %%
# Create empty list to store product details
# Loop through product links
# Send request to each product page
# Parse HTML
# Extract description
# Extract genre
# Extract product information table
# Store extracted data in list

# %%
all_product_details = []

for url in product_links:
    
    # Send request to each product page
    # Parse HTML
    page_response = requests.get(url)
    page_soup = BeautifulSoup(page_response.content, 'html.parser')
  

    # Extract description
    description_header = page_soup.find(id = 'product_description')
    description = description_header.find_next_sibling('p').text.strip() if description_header else "N/A"
    # print(description)
    
    # Extract Genre
    breadcrumb = page_soup.find('ul', class_ = 'breadcrumb')
    genre = breadcrumb.find_all('li')[2].text.strip()
    
    # Product Information
    
    table = page_soup.find('table', class_ = 'table-striped')
    product_info = {}

    for row in table.find_all('tr'):
        col_name = row.find('th').text.strip()
        col_value = row.find('td').text.strip()
        product_info[col_name] = col_value
        
    product_info['Description'] = description
    product_info['Genre'] = genre
    
    all_product_details.append(product_info)
    
print(f"Scrapped {len(all_product_details)} Product pages")
# Out:
# Scrapped 20 Product pages

# %%
all_product_details
# Out:
# [{'UPC': 'a897fe39b1053632',
#   'Product Type': 'Books',
#   'Price (excl. tax)': '£51.77',
#   'Price (incl. tax)': '£51.77',
#   'Tax': '£0.00',
#   'Availability': 'In stock (22 available)',
#   'Number of reviews': '0',
# ...

# %% [markdown]
# ## Convert Scraped Data into a Pandas DataFrame
#
# After collecting product information from multiple pages, we will organize the data into a structured dataset.
#
# Pandas DataFrames allow us to represent data in a tabular format similar to spreadsheets.
#
# Each key in our dictionary will become a column in the dataset.

# %%
# Convert scraped data list into a pandas DataFrame

# Display first few rows
import pandas as pd
details_df = pd.DataFrame(all_product_details)

details_df.head()
# Out:
#                 UPC Product Type Price (excl. tax) Price (incl. tax)    Tax  \
# 0  a897fe39b1053632        Books            £51.77            £51.77  £0.00
# 1  90fa61229261140a        Books            £53.74            £53.74  £0.00
# 2  6957f44c3847a760        Books            £50.10            £50.10  £0.00
# 3  e00eb4fd7b871a48        Books            £47.82            £47.82  £0.00
# 4  4165285e1663650f        Books            £54.23            £54.23  £0.00
#
#               Availability Number of reviews  \
# 0  In stock (22 available)                 0
# 1  In stock (20 available)                 0
# 2  In stock (20 available)                 0
# 3  In stock (20 available)                 0
# 4  In stock (20 available)                 0
#
#                                          Description               Genre
# 0  It's hard to imagine a world without A Light i...              Poetry
# 1  "Erotic and absorbing...Written with starling ...  Historical Fiction
# ...

# %%
listing_df.head()
# Out:
#                                    Title   Price  Rating Stock Availability
# 0                   A Light in the Attic  £51.77       3           In stock
# 1                     Tipping the Velvet  £53.74       1           In stock
# 2                             Soumission  £50.10       1           In stock
# 3                          Sharp Objects  £47.82       4           In stock
# 4  Sapiens: A Brief History of Humankind  £54.23       5           In stock

# %% [markdown]
# ## Combine Listing Page Data with Product Page Data
#
# We previously created a dataset from the listing page that contains:
#
# - Title
# - Price
# - Rating
# - Availability
#
# Now we want to combine that dataset with the new product page information.
#
# This will create a **complete dataset containing all book information**.

# %%
# Combine existing dataset with product details dataset
# Display final dataset
final_df = pd.concat([listing_df, details_df], axis = 1)

# %%
final_df.head()
# Out:
#                                    Title   Price  Rating Stock Availability  \
# 0                   A Light in the Attic  £51.77       3           In stock
# 1                     Tipping the Velvet  £53.74       1           In stock
# 2                             Soumission  £50.10       1           In stock
# 3                          Sharp Objects  £47.82       4           In stock
# 4  Sapiens: A Brief History of Humankind  £54.23       5           In stock
#
#                 UPC Product Type Price (excl. tax) Price (incl. tax)    Tax  \
# 0  a897fe39b1053632        Books            £51.77            £51.77  £0.00
# 1  90fa61229261140a        Books            £53.74            £53.74  £0.00
# 2  6957f44c3847a760        Books            £50.10            £50.10  £0.00
# 3  e00eb4fd7b871a48        Books            £47.82            £47.82  £0.00
# 4  4165285e1663650f        Books            £54.23            £54.23  £0.00
#
#               Availability Number of reviews  \
# ...

# %%
import re 

final_df['Availability'] = final_df['Availability'].str.extract(r'(\d+)').astype(int)

# %%
final_df.head()
# Out:
#                                    Title   Price  Rating Stock Availability  \
# 0                   A Light in the Attic  £51.77       3           In stock
# 1                     Tipping the Velvet  £53.74       1           In stock
# 2                             Soumission  £50.10       1           In stock
# 3                          Sharp Objects  £47.82       4           In stock
# 4  Sapiens: A Brief History of Humankind  £54.23       5           In stock
#
#                 UPC Product Type Price (excl. tax) Price (incl. tax)    Tax  \
# 0  a897fe39b1053632        Books            £51.77            £51.77  £0.00
# 1  90fa61229261140a        Books            £53.74            £53.74  £0.00
# 2  6957f44c3847a760        Books            £50.10            £50.10  £0.00
# 3  e00eb4fd7b871a48        Books            £47.82            £47.82  £0.00
# 4  4165285e1663650f        Books            £54.23            £54.23  £0.00
#
#    Availability Number of reviews  \
# ...

# %%
final_df.shape
# Out:
# (20, 13)

# %%
# Save final dataset as CSV file

# Verify file creation
