# %% [markdown]
# ## What is a Database?
#
# A database is an organized collection of data that allows:
# - Efficient storage
# - Easy retrieval
# - Secure management of data
#
# Databases are used in:
# - Websites
# - Mobile apps
# - Data analysis
# - Enterprise systems

# %% [markdown]
# ## Why Databases Instead of Files?
#
# Problems with files:
# - Data duplication
# - No structure
# - Difficult searching
# - No concurrency control
#
# Databases solve these problems.

# %% [markdown]
# ## What is SQL?
#
# SQL (Structured Query Language) is used to:
# - Create database objects
# - Insert data
# - Retrieve data
# - Update data
# - Delete data

# %% [markdown]
# ## Types of SQL Commands
#
# - DDL (Data Definition Language)
#   - CREATE
#   - DROP
#   - ALTER
#
# - DML (Data Manipulation Language)
#   - INSERT
#   - UPDATE
#   - DELETE
#
# - DQL (Data Query Language)
#   - SELECT

# %% [markdown]
# ## What is SQLite?
#
# SQLite is a lightweight database:
# - No server required
# - Stored as a single file
# - Easy to use with Python

# %% [markdown]
# ## SQLite vs Other Databases
#
# SQLite is best for:
# - Learning
# - Prototyping
# - Small applications
#
# Not ideal for:
# - Large concurrent systems

# %% [markdown]
# ## sqlite3 Module in Python
#
# Python provides sqlite3 module to work with SQLite databases.
#
# Main steps:
# 1. Connect to database
# 2. Create cursor
# 3. Execute SQL
# 4. Commit changes
# 5. Close connection

# %%
# Import sqlite3 module
import sqlite3


# Connect to SQLite database file
conn = sqlite3.connect("college.db") # Creates a database files if not exists


# Create cursor object
cursor = conn.cursor()

# %% [markdown]
# ## Creating Tables
#
# Tables consist of:
# - Columns
# - Data types
#
# Common SQLite data types:
# - INTEGER
# - TEXT
# - REAL

# %%
# Write SQL query to create table named students
# Columns:
# id -> integer primary key
# name -> text
# age -> integer
# course -> text
create_table_query = """ 
CREATE TABLE IF NOT EXISTS  students (
    id INTEGER PRIMARY KEY,
    name TEXT,
    age INTEGER,
    course TEXT
    
)

"""


# Execute create table query
cursor.execute(create_table_query)

# %% [markdown]
# ## IF NOT EXISTS
#
# This prevents errors if table already exists.

# %%
# Modify create table query using IF NOT EXISTS

# %% [markdown]
# ## Inserting Records
#
# INSERT INTO is used to add data into table.

# %%
# Write SQL query to insert one student record
insert_one_record = """
INSERT INTO students (id,name,age,course)
VALUES (1,'Ram', 21, 'Data Science')

"""

# Execute insert query
cursor.execute(insert_one_record)


# Commit changes
conn.commit()

# %% [markdown]
# ## Parameterized Queries
#
# Parameterized queries prevent SQL injection.

# %%
# Write insert query using placeholders (?)

insert_param_query = """ 
INSERT INTO students (id, name, age, course)
VALUES(?,?,?,?)
"""
# Pass values separately
cursor.execute(insert_param_query,(2, "Sita", 22, "Python"))

# commit chnages
conn.commit()

# %% [markdown]
# ## Inserting Multiple Rows
#
# We can insert multiple records using executemany().

# %%
# Create list of multiple student records
students_data = [
    (3, "Hari",24, "Python"),
    (4,"Laxman", 25, "Data Science"),
    (5,"Gita", 24, "Python"),
    (6, "Krishna", 20, "Machine Learning")
]

# Write insert query with placeholders
insert_many_query = """ 
INSERT INTO students (id, name, age, course)
VALUES(?,?,?,?)
"""

# Use executemany()
cursor.executemany(insert_many_query, students_data)

# Commit changes
conn.commit()

# %% [markdown]
# ## Fetching Data from Database
#
# SELECT is used to retrieve records.

# %%
# Write select query to fetch all records

select_all_query = """SELECT * From students"""

# Execute select query
cursor.execute(select_all_query)

# Fetch all rows
rows = cursor.fetchall()
# print(rows)

# Print rows one by one
for row in rows:
    print(row)
# Out:
# (1, 'Ram', 21, 'Data Science')
# (2, 'Sita', 22, 'Python')
# (3, 'Hari', 24, 'Python')
# (4, 'Laxman', 25, 'Data Science')
# (5, 'Gita', 24, 'Python')
# (6, 'Krishna', 20, 'Machine Learning')

# %% [markdown]
# ## fetchone() vs fetchall()

# %%
# Fetch only one record using fetchone()
# Execute select query
cursor.execute(select_all_query)

one_row = cursor.fetchone()
print(one_row)

# fetch all records using fetchall()
# Out:
# (1, 'Ram', 21, 'Data Science')

# %% [markdown]
# ### Write select query with WHERE condition
#
#
# ### Execute and fetch filtered records
#
# ### Comparison Operators in SQL
#
# - `=`
# - `>`
# - `<`
# - `>=`
# - `<=`

# %%
where_query = """SELECT * From students WHERE age > 22"""

cursor.execute(where_query)

rows = cursor.fetchall()
for row in rows:
    print(row)
# Out:
# (3, 'Hari', 24, 'Python')
# (4, 'Laxman', 25, 'Data Science')
# (5, 'Gita', 24, 'Python')

# %% [markdown]
# ## ORDER BY Clause
#
# Used to sort records in ascending or descending order.

# %%
# Write select query using ORDER BY age
order_query = "SELECT * FROM students ORDER BY age DESC"

cursor.execute(order_query)
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, 'Laxman', 25, 'Data Science')
# (3, 'Hari', 24, 'Python')
# (5, 'Gita', 24, 'Python')
# (2, 'Sita', 22, 'Python')
# (1, 'Ram', 21, 'Data Science')
# (6, 'Krishna', 20, 'Machine Learning')

# %% [markdown]
# ## UPDATE Statement
#
# Used to modify existing records.

# %%
# Write update query using WHERE clause
update_query = """
UPDATE students 
SET age = 25
WHERE name = 'Krishna'
"""
# Execute update query
cursor.execute(update_query)

# Commit changes
conn.commit()

# %%
# Write select query using ORDER BY age
order_query = "SELECT * FROM students ORDER BY age DESC"

cursor.execute(order_query)
rows = cursor.fetchall()

for row in rows:
    print(row)
# Out:
# (4, 'Laxman', 25, 'Data Science')
# (6, 'Krishna', 25, 'Machine Learning')
# (3, 'Hari', 24, 'Python')
# (5, 'Gita', 24, 'Python')
# (2, 'Sita', 22, 'Python')
# (1, 'Ram', 21, 'Data Science')

# %%
#Change the course of Krishna from Machine Learning to Data Science

# %% [markdown]
# ## DELETE Statement
#
# Used to remove records from table.

# %%
# Write delete query using WHERE condition
delete_query = "DELETE FROm students Where age <=21"

# Execute delete query
cursor.execute(delete_query)


# Commit changes
conn.commit()

# %%
# Write select query to fetch all records

select_all_query = """SELECT * From students"""

# Execute select query
cursor.execute(select_all_query)

# Fetch all rows
rows = cursor.fetchall()
# print(rows)

# Print rows one by one
for row in rows:
    print(row)
# Out:
# (2, 'Sita', 22, 'Python', None)
# (3, 'Hari', 24, 'Python', None)
# (4, 'Laxman', 25, 'Data Science', None)
# (5, 'Gita', 24, 'Python', None)
# (6, 'Krishna', 25, 'Machine Learning', None)

# %%
# ALTER / DROP
alter_add_column_query = """
ALTER TABLE students
ADD COLUMN email TEXT
"""

cursor.execute(alter_add_column_query)

conn.commit()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[24], line 7
#       1 # ALTER / DROP
#       2 alter_add_column_query = """
#       3 ALTER TABLE students
#       4 ADD COLUMN email TEXT
#       5 """
# ----> 7 cursor.execute(alter_add_column_query)
#       9 conn.commit()
#      12 # DROP
#
# OperationalError: duplicate column name: email

# %%
# DROP 

drop_table_query = "DROP TABLE IF EXISTS old_students"
cursor.execute(drop_table_query)
conn.commit()

# %% [markdown]
# ## Why Commit is Important?
#
# Without commit:
# - Changes are temporary
# - Data may be lost

# %%
# Commit database changes

# %% [markdown]
# ## Closing Database Connection
#
# Always close connection to free resources.

# %%
# Close database connection
conn.close()

# %% [markdown]
# ## SQL Injection
#
# Never directly insert user input into SQL queries.
#
# Always use parameterized queries.
