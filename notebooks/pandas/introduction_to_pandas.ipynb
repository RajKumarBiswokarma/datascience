# %% [markdown]
# ## What is Pandas?
#
# Pandas is a powerful Python library that is specifically designed to work on data frames that have "relational" or "labeled" data. Its aim aligns with doing real-world data analysis using Python.
#
# This Python package works well for data manipulation, operating a dataset, exploring a data frame, data analysis, and machine learning-related tasks.
#
# ## Key Features of Pandas
#
# - Fast and efficient DataFrame object with default and customized indexing.
# - Tools for loading data into in-memory data objects from different file formats.
# - Data alignment and integrated handling of missing data.
# - Reshaping and pivoting of date sets.
# - Label-based slicing, indexing and subsetting of large data sets.
# - Columns from a data structure can be deleted or inserted.
# - Group by data for aggregation and transformations.
# - High performance merging and joining of data.
# - Time Series functionality.
#
# Pandas is a Python library used for:
# - Data analysis
# - Data manipulation
# - Data cleaning
#
# It is built on top of NumPy and is widely used in:
# - Data Science
# - Machine Learning
# - Business Analytics
#
#
# ## Why Use Pandas?
#
# Pandas provides:
# - Easy data handling
# - Tabular data structure
# - Built-in data cleaning tools
# - Fast data operations

# %%
# import pandas library

import pandas as pd

# %% [markdown]
# ## Main Data Structures in Pandas
#
# 1. Series → A one-dimensional labeled homogeneous array, size immutable.
#
# 2. DataFrame → A two-dimensional labeled, size-mutable tabular structure with potentially heterogeneously typed columns.

# %% [markdown]
# ## What is a Series?
#
# A Series is:
# - One-dimensional
# - Labeled array
# - Similar to a column in a table
# - Store integers, strings, floating numbers etc
#
# Each value in a Series is associated with a label (index), which can be an integer or a string.
#
# A Series is similar to a one-dimensional ndarray (NumPy array) but with labels, which are also known as indices.
#
# These labels can be used to access the data within the Series.
#
#
# ### Key Points
# - Homogeneous data
# - Size immutable
# - values of Data Mutable

# %%
# Create a pandas Series from a list
list_1 =  [1,2,3]

myser = pd.Series(list_1)
# Display the series
print(myser)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
print(myser[1])
# Out:
# 2

# %%
# Create a pandas Series with custom index labels
custom_index_series = pd.Series(list_1, index = ["a","b","c"])
print(custom_index_series)
# Out:
# a    1
# b    2
# c    3
# dtype: int64

# %%
print(custom_index_series["c"])
# Out:
# 3

# %%
print(custom_index_series[["a","c"]])
# Out:
# a    1
# c    3
# dtype: int64

# %%
# Create a series from python dictionary
data = {
    "Name": ["Ram", "Hari", "Laxman"],
    "Age": [21,22,23],
    "Course": ["Python", "Data Science", "AI"]
}
data = pd.Series(data)
print(data)
# Out:
# Name             [Ram, Hari, Laxman]
# Age                     [21, 22, 23]
# Course    [Python, Data Science, AI]
# dtype: object

# %%
# Create a series from python dictionary
data = {
    "Name": ["Ram", "Hari", "Laxman"],
    "Age": [21,22,23],
    "Course": ["Python", "Data Science", "AI"]
}
data = pd.Series(data, index = ["Name", "Age"])
print(data)
# Out:
# Name    [Ram, Hari, Laxman]
# Age            [21, 22, 23]
# dtype: object

# %%
# Access a value using index label
print(data["Name"])

# Access multiple values
print(data[["Name","Age"]])
# Out:
# ['Ram', 'Hari', 'Laxman']
# Name    [Ram, Hari, Laxman]
# Age            [21, 22, 23]
# dtype: object

# %% [markdown]
# ## What is a DataFrame?
#
#
# A DataFrame is:
# - Two-dimensional table
# - Rows and columns
# - Like an Excel sheet
#
#  It is similar to a table in a database or a spreadsheet.
#
#
#
# ## Key Points
# - Heterogeneous data
# - Size Mutable
# - Data Mutable
#
#
#  For instance, a DataFrame is a container for Series, and a Series is a container for scalars. This flexibility allows for efficient data manipulation and storage.

# %%
# Create a DataFrame from a dictionary
data = {
    "Name": ["Ram", "Hari", "Laxman", "Sita", "Raj", "Ravan", "Krishna"],
    "Age": [21,22,23,24,25,26,27],
    "Course": ["Python", "Data Science", "AI","Python", "Data Science", "AI", "AI"]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age        Course
# 0      Ram   21        Python
# 1     Hari   22  Data Science
# 2   Laxman   23            AI
# 3     Sita   24        Python
# 4      Raj   25  Data Science
# 5    Ravan   26            AI
# 6  Krishna   27            AI

# %%
# Display first few rows
print(df.head())
# Out:
#      Name  Age        Course
# 0     Ram   21        Python
# 1    Hari   22  Data Science
# 2  Laxman   23            AI
# 3    Sita   24        Python
# 4     Raj   25  Data Science

# %%
# Display last few rows
print(df.tail())
# Out:
#       Name  Age        Course
# 2   Laxman   23            AI
# 3     Sita   24        Python
# 4      Raj   25  Data Science
# 5    Ravan   26            AI
# 6  Krishna   27            AI

# %%
# Display column names
print(df.columns)

# Display shape of DataFrame
print(df.shape)
# Out:
# Index(['Name', 'Age', 'Course'], dtype='str')
# (7, 3)

# %%
# Select a single column
print(df["Age"])
print()

# Select multiple columns
print(df[["Name","Age"]])
# Out:
# 0    21
# 1    22
# 2    23
# 3    24
# 4    25
# 5    26
# 6    27
# Name: Age, dtype: int64
#
#       Name  Age
# 0      Ram   21
# 1     Hari   22
# 2   Laxman   23
# 3     Sita   24
# 4      Raj   25
# 5    Ravan   26
# 6  Krishna   27

# %%
# Select rows using index
print(df.iloc[0])
print()

# Select rows using label-based selection
print(df.loc[1])
# Out:
# Name         Ram
# Age           21
# Course    Python
# Name: 0, dtype: object
#
# Name              Hari
# Age                 22
# Course    Data Science
# Name: 1, dtype: object

# %% [markdown]
# ## Data Import
#
# The Pandas library offers powerful I/O tools (API) for data import and export, enabling seamless handling of various file formats like CSV, Excel, JSON, and many more.
#
# This API includes top-level reader functions like, pd.read_csv(), read_clipboard() and corresponding writer methods like, to_csv(), to_clipboard() for easy data handling.
#
#
#
#
#
# | Format                 | Reader Function     | Writer Function     |
# |------------------------|---------------------|---------------------|
# | Tabular Data           | `read_table()`      | NA                  |
# | CSV                    | `read_csv()`        | `to_csv()`          |
# | Fixed-Width Text File  | `read_fwf()`        | NA                  |
# | Clipboard              | `read_clipboard()`  | `to_clipboard()`    |
# | Pickling               | `read_pickle()`     | `to_pickle()`       |
# | Excel                  | `read_excel()`      | `to_excel()`        |
# | JSON                   | `read_json()`       | `to_json()`         |
# | HTML                   | `read_html()`       | `to_html()`         |
# | XML                    | `read_xml()`        | `to_xml()`          |
# | LaTeX                  | NA                  | `to_latex()`        |
# | HDF5 Format            | `read_hdf()`        | `to_hdf()`          |
# | Feather                | `read_feather()`    | `to_feather()`      |
# | Parquet                | `read_parquet()`    | `to_parquet()`      |
# | ORC                    | `read_orc()`        | `to_orc()`          |
# | SQL                    | `read_sql()`        | `to_sql()`          |
# | Stata                  | `read_stata()`      | `to_stata()`        |

# %%
# Load a CSV file into DataFrame
data = pd.read_csv("/home/fm-pc-lt-269/Desktop/data_science/notebooks/pandas/data/weather.csv", skiprows=1,header = 0)


# Display first few rows
print(data.head())
# Out:
#         day    temperature     windspeed     event
# 0  1/1/2017             32             6      Rain
# 1  1/4/2017  not available             9     Sunny
# 2  1/5/2017             -1  not measured      Snow
# 3  1/6/2017  not available             7  no event
# 4  1/7/2017             32  not measured      Rain

# %%
# Load an Excel file into DataFrame
dataframe = pd.read_excel("../pandas/data/weather_data.xlsx")
print(dataframe.head())
# Out:
#   This is a data of weather     Unnamed: 1    Unnamed: 2 Unnamed: 3
# 0                       day    temperature     windspeed      event
# 1                  1/1/2017             32             6       Rain
# 2                  1/4/2017  not available             9      Sunny
# 3                  1/5/2017             -1  not measured       Snow
# 4                  1/6/2017  not available             7   no event

# %%
# !pip install openpyxl

# %%
# Load a JSON file into DataFrame
# Create synthetic dataset
data = {
    "StudentID": [1, 2, 3, 4, 5, 5],   # duplicate ID included
    "Name": ["Ram", "Sita", "Hari", "Gita", "Nabin", "Nabin"],
    "Age": [21, 22, None, 23, 24, 24],   # missing value included
    "Course": ["Python", "DS", "AI", None, "ML", "ML"],  # missing value
    "Score": [85, 90, 88, None, 92, 92]  # missing value
}

df = pd.DataFrame(data)
# print(df)
5.00000
# Save DataFrame to JSON file
df.to_json("data/students.json", orient="records", indent=4)

df_json = pd.read_json("data/students.json")
print(df_json)
# Out:
#    StudentID   Name   Age  Course  Score
# 0          1    Ram  21.0  Python   85.0
# 1          2   Sita  22.0      DS   90.0
# 2          3   Hari   NaN      AI   88.0
# 3          4   Gita  23.0     NaN    NaN
# 4          5  Nabin  24.0      ML   92.0
# 5          5  Nabin  24.0      ML   92.0

# %%
# Display data types
print(df_json.dtypes)

# Display summary statistics


# Display basic information
# Out:
# StudentID      int64
# Name             str
# Age          float64
# Course           str
# Score        float64
# dtype: object

# %%
print(df_json.describe())
# Out:
#        StudentID       Age      Score
# count   6.000000   5.00000   5.000000
# mean    3.333333  22.80000  89.400000
# std     1.632993   1.30384   2.966479
# min     1.000000  21.00000  85.000000
# 25%     2.250000  22.00000  88.000000
# 50%     3.500000  23.00000  90.000000
# 75%     4.750000  24.00000  92.000000
# max     5.000000  24.00000  92.000000

# %%
print(df_json.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   StudentID  6 non-null      int64
#  1   Name       6 non-null      str
#  2   Age        5 non-null      float64
#  3   Course     5 non-null      str
#  4   Score      5 non-null      float64
# dtypes: float64(2), int64(1), str(2)
# memory usage: 372.0 bytes
# None

# %% [markdown]
# ## Exporting Data (Optional)
#
# Pandas can save data to:
# - CSV
# - Excel
# - JSON

# %%
# Save DataFrame to CSV file
