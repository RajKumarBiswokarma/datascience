# %% [markdown]
# ## Tuples & Sets in Python
#
#
# ## Tuples in Python
#
# ### What is a Tuple?
# A tuple is an **ordered and immutable** collection of elements.
#
# Key points:
# - Similar to lists but **cannot be modified**
# - Allows duplicate values
# - Faster than lists
# - Used for fixed data
#
# ### Why Use Tuples?
# - To protect data from changes
# - To represent constant values
# - Used in functions (returning multiple values)
#
# Tuples are defined using **parentheses `( )`**.

# %%
# Create a tuple
tuple1 = (1, 2, 3)
print(tuple1)
# Out:
# (1, 2, 3)

# %%
# Create Tuple With One Item
mytuple = ("Python",)
print(mytuple)
print(type(mytuple))


# mytuple = tuple(("1","2","3"))
# print(mytuple)
# Out:
# ('Python',)
# <class 'tuple'>

# %%
# Access Tuple Itemsprint
print(mytuple[0])
print(mytuple[-1])
print(mytuple[2:3])
# Out:
# 1
# 3
# ('3',)

# %%
# Check if Item Exists
mytuple = ("Python", "Java", "C", "C++", "Kotlin")

if "Java" in mytuple:
    print("Java Exists")
# Out:
# Java Exists

# %% [markdown]
# ## Update Tuples
#
# Tuples are unchangeable, meaning that you cannot change, add, or remove items once the tuple is created.

# %% [markdown]
# ##

# %%
new_list = list(mytuple)
print(new_list)


new_list.append("Swift")
print(new_list)

mytuple = tuple(new_list)
print(type(mytuple))
# Out:
# ['Python', 'Java', 'C', 'C++', 'Kotlin']
# ['Python', 'Java', 'C', 'C++', 'Kotlin', 'Swift']
# <class 'tuple'>

# %% [markdown]
# ## Unpack Tuples
#
# When we create a tuple, we normally assign values to it. This is called "packing" a tuple:

# %%
fruit_tuple = ("Strawberry", "Orange", "Blueberry")
red, orange, blue = fruit_tuple
print(red)
print(orange)
print(blue)

fruit_tuple = ("Strawberry", "Orange", "Blueberry", "Apple")
red, orange, *others = fruit_tuple
print(red)
print(orange)
print(others)
print(type(others))
# Out:
# Strawberry
# Orange
# Blueberry
# Strawberry
# Orange
# ['Blueberry', 'Apple']
# <class 'list'>

# %%
fruit_tuple = fruit_tuple * 2
print(fruit_tuple)
# Out:
# ('Strawberry', 'Orange', 'Blueberry', 'Apple', 'Strawberry', 'Orange', 'Blueberry', 'Apple')

# %% [markdown]
# ## Set in Python
#
# ### What is a Set?
# A set is an **unordered and mutable** collection of unique elements.
#
# Key points:
# - No duplicate values allowed
# - Order is not preserved
# - Used for uniqueness and membership testing
#
# Sets are defined using **curly braces `{ }`**.

# %%
# Create a set
myset = {"python", "java", "c", "c++"}
print(myset)

myset.pop()
print(myset)

new_set = {1, 2, 2, 3, 4, 4, 5}
print(new_set)

new_set = {4, 5, 6, 9, 1, 2}
print(new_set)

# Access item of Set using loop

for item in new_set:
    print(item)


# Add an element to the set
myset.add("Kotlin")
print(myset)

myset.update(new_set)
print(myset)

# Remove an element from the set
myset.remove("Kotlin")
print(myset)

myset.discard("c++")
print(myset)

myset.pop()
print(myset)


# Check if an element exists in the set

print("python" in myset)
# Out:
# {'java', 'c', 'c++', 'python'}
# {'c', 'c++', 'python'}
# {1, 2, 3, 4, 5}
# {1, 2, 4, 5, 6, 9}
# 1
# 2
# 4
# 5
# 6
# 9
# {'python', 'Kotlin', 'c++', 'c'}
# {1, 2, 4, 5, 6, 9, 'python', 'Kotlin', 'c++', 'c'}
# {1, 2, 4, 5, 6, 9, 'python', 'c++', 'c'}
# {1, 2, 4, 5, 6, 9, 'python', 'c'}
# {2, 4, 5, 6, 9, 'python', 'c'}
# True

# %% [markdown]
# ## Frozenset Methods in Python
#
# A `frozenset` is an **immutable version of a set**.
#
# Because it is immutable:
# - You **cannot add or remove** elements
# - Methods that modify a set are **not available**
#
# However, frozensets support all **non-mutating set operations** that return a **new frozenset**.
#
# ---
#
# | Method | Shortcut | Description |
# |------|---------|-------------|
# | `copy()` | — | Returns a shallow copy of the frozenset |
# | `difference()` | `-` | Returns a new frozenset with the difference |
# | `intersection()` | `&` | Returns a new frozenset with the intersection |
# | `isdisjoint()` | — | Returns True if two frozensets have no common elements |
# | `issubset()` | `<=` / `<` | Checks if this frozenset is a (proper) subset |
# | `issuperset()` | `>=` / `>` | Checks if this frozenset is a (proper) superset |
# | `symmetric_difference()` | `^` | Returns a new frozenset with symmetric differences |
# | `union()` | `|` | Returns a new frozenset containing the union |

# %%
fs1 = frozenset([1, 2, 3, 4])
fs2 = frozenset([3, 4, 5, 6])

print("Frozenset 1:", fs1)
print("Frozenset 2:", fs2)


# Union
print("Union:", fs1.union(fs2))

# Intersection
print("Intersection:", fs1.intersection(fs2))

# Difference
print("Difference:", fs1.difference(fs2))

# Symmetric Difference
print("Symmetric Difference:", fs1.symmetric_difference(fs2))

# Subset & Superset
print("Is subset:", fs1.issubset(fs2))
print("Is superset:", fs1.issuperset({1, 2}))
# Out:
# frozenset()
# frozenset({4, 5})

# %% [markdown]
# ## Set Methods in Python
#
# Python provides several built-in methods to perform operations on sets.
#
# These methods are mainly used for:
# - Adding and removing elements
# - Performing mathematical set operations
# - Checking relationships between sets
#
# ---
#
# | Method | Shortcut | Description |
# |------|---------|-------------|
# | `add()` | — | Adds an element to the set |
# | `clear()` | — | Removes all elements from the set |
# | `copy()` | — | Returns a copy of the set |
# | `difference()` | `-` | Returns a set containing the difference between sets |
# | `difference_update()` | `-=` | Removes items found in another set |
# | `discard()` | — | Removes the specified element (no error if not found) |
# | `intersection()` | `&` | Returns the intersection of two sets |
# | `intersection_update()` | `&=` | Keeps only common elements |
# | `isdisjoint()` | — | Returns True if sets have no common elements |
# | `issubset()` | `<=` | Checks if set is a subset of another |
# | `issuperset()` | `>=` | Checks if set is a superset of another |
# | `pop()` | — | Removes a random element |
# | `remove()` | — | Removes the specified element |
# | `symmetric_difference()` | `^` | Returns elements not common to both sets |
# | `symmetric_difference_update()` | `^=` | Updates set with symmetric differences |
# | `union()` | `|` | Returns the union of sets |
# | `update()` | `|=` | Updates set with union of sets |

# %%
# Create two sets
set_a = {1, 2, 3, 4}
set_b = {3, 4, 5, 6}

print("Set A:", set_a)
print("Set B:", set_b)

# Add an element to a set
set_a.add(10)
print("\nAfter adding 10 to Set A:", set_a)

# Remove an element using remove()
set_a.remove(10)   # Raises error if element not found
print("After remove(10) from Set A:", set_a)

# Remove an element using discard()
set_a.discard(100)  # No error even if element not found
print("After discard(100) from Set A:", set_a)

# Find union of two sets
union_set = set_a.union(set_b)
print("\nUnion of Set A and Set B:", union_set)

# Find intersection of two sets
intersection_set = set_a.intersection(set_b)
print("Intersection of Set A and Set B:", intersection_set)

# Find difference between sets
difference_set = set_a.difference(set_b)
print("Difference (Set A - Set B):", difference_set)

# Find symmetric difference
symmetric_diff = set_a.symmetric_difference(set_b)
print("Symmetric Difference:", symmetric_diff)

# Check subset and superset
print("\nIs Set A a subset of Set B?", set_a.issubset(set_b))
print("Is Set A a superset of Set B?", set_a.issuperset(set_b))

# Copy the set
set_c = set_a.copy()
print("\nCopied Set (Set C):", set_c)

# Clear the set
set_c.clear()
print("After clearing Set C:", set_c)

# %% [markdown]
# ## Differences Between List, Tuple, and Set
#
# | Feature | List | Tuple | Set |
# |------|------|------|------|
# | Ordered | Yes | Yes | No |
# | Mutable | Yes | No | Yes |
# | Allows Duplicates | Yes | Yes | No |
# | Syntax | `[ ]` | `( )` | `{ }` |
# | Use Case | General purpose | Fixed data | Unique data |

# %% [markdown]
# # Dictionaries in Python
# ## Key–Value Operations
#
# ---
#
# ## What is a Dictionary?
#
# A dictionary is a collection of **key–value pairs**.
#
# Key characteristics:
# - Unordered (in concept)
# - Mutable (can be changed)
# - Keys are **unique**
# - Values can be of any data type
#
# Dictionaries are widely used to represent **structured data**.
#
# Examples:
# - Student records
# - Configuration settings
# - JSON-like data
#
# Dictionaries are created using **curly braces `{ }`**.

# %%
# Create a dictionary with student details
student_dict = {
    "name": "Raj",
    # "Course": "Data Science",
    "Marks": 87,
}

# Print the dictionary
print(student_dict)
# Out:
# {'name': 'Raj', 'Marks': 87}

# %% [markdown]
# ## Dictionary Items
#
# Dictionary items are ordered, changeable, and do not allow duplicates.
#
# Dictionary items are presented in key:value pairs, and can be referred to by using the key name.

# %% [markdown]
# ## Accessing Dictionary Elements
#
# Dictionary values are accessed using **keys**, not indexes.
#
# Syntax:
# `dictionary[key]` or `dictionary.get(key) `

# %%
# Access a value using key
student_dict["name"]
print(student_dict["name"])

# Access a value using get()
student_dict.get("Course", "Python")

print(student_dict)
# Out:
# Raj
# {'name': 'Raj', 'Marks': 87}

# %% [markdown]
# ## Adding and Updating Dictionary Items
#
# Dictionaries allow:
# - Adding new key–value pairs
# - Updating existing values
#
# If the key already exists, the value is updated.
# If the key does not exist, a new key–value pair is created.

# %%
# Add a new key-value pair
student_dict["course"] = "Python"
student_dict["institute"] = "TechAxis"
print(student_dict)

# Update an existing value
student_dict["name"] = "kamal"
print(student_dict)
# Out:
# {'name': 'kamal', 'course': 'Python', 'institute': 'TechAxis'}
# {'name': 'kamal', 'course': 'Python', 'institute': 'TechAxis'}

# %% [markdown]
# ## Removing Dictionary Items
#
# Python provides multiple ways to remove data:
# - `pop()` → removes item using key
# - `del` → deletes item
# - `clear()` → removes all items

# %%
# Remove an item using pop()
student_dict = {
    "name": "Raj",
    "Course": "Data Science",
    "Marks": 87,
}
student_dict.pop("Marks")
print(student_dict)

# Remove an item using del
del student_dict["Course"]
print(student_dict)


# Clear the dictionary
student_dict.clear()
print(student_dict)
# Out:
# {'name': 'Raj', 'Course': 'Data Science'}
# {'name': 'Raj'}
# {}

# %% [markdown]
# ## Dictionary Methods (Common)
#
# Some commonly used dictionary methods:
# - `keys()`
# - `values()`
# - `items()`
# - `update()`
# - `copy()`

# %%
# Get all keys
student_dict = {
    "name": "Raj",
    "Course": "Data Science",
    "Marks": 87,
}
print(student_dict.keys())

# Get all values
print(student_dict.values())


# Get all key-value pairs


# Update dictionary using update()


# Copy the dictionary
# Out:
# dict_keys(['name', 'Course', 'Marks'])
# dict_values(['Raj', 'Data Science', 87])

# %% [markdown]
# ## Nested Dictionaries
#
# A dictionary can contain dictionaries, this is called nested dictionaries.

# %%
student = {
    1: {
        "Name": "Abc",
        "Address": {"City": "Kathmandu", "Ward": 10},
        "Subjects": {"Science": {"Biology": 87, "Botany": 78}, "Math": 80},
    },
    2: {
        "Name": "Xyz",
        "Address":{
            "City": "Kathmandu",
            "Ward": 10
        },
        "Subjects":{
            "Science":{
                "Biology": 87,
                "Botany":78
                
            },
            "Math":80
        }
        
    },
}

print(student[2]["Subjects"]["Science"]["Biology"])
# Out:
# 87

# %% [markdown]
# "
